# %% [markdown]
# # Final Project: Integrated Data Analysis Project
# ## Subject: Homelessness
#
# The goal is to analyze homeless shelters across the U.S. to identify areas and times that need additional resources and shelter development, along with the costs of such development.

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# ## Data Sourcing
#
# I found this dataset by searching for homelessness datasets in Kaggle:
#
# https://www.kaggle.com/datasets/shamimhasan8/homelessness-and-shelter-data
#
# There are various websites that show prices of available land in certain regions. This dataset provides a good aggregation of land prices across the entire U.S:
#
# https://www.aei.org/housing/land-price-indicators/

# %%
shelters = pd.read_csv("homelessness_shelter_data.csv")
res_land_price = pd.read_excel("AEI_adjusted-Land-Data-2024-1.xlsx", sheet_name="CBSA")

# %% [markdown]
# ## Data Preparation and Integration
# ### Exploratory Data Analysis
# #### Overview of the Dataframes' Features

# %%
shelters.head()
# Out:
#    id        date     shelter_name         city state  total_capacity  \
# 0   1  2023-10-05  Sunrise Shelter       Dallas    TX              85
# 1   2  2023-08-01       Safe Haven       Dallas    TX             128
# 2   3  2025-04-27    Second Chance     San Jose    CA             190
# 3   4  2024-10-05      Harbor Home     San Jose    CA             115
# 4   5  2024-09-15      Harbor Home  San Antonio    TX             155
#
#    occupied_beds  available_beds  occupancy_rate  average_age  \
# 0             62              23            72.9           19
# 1            117              11            91.4           58
# 2            144              46            75.8           56
# 3              7             108             6.1           63
# 4             65              90            41.9           21
#
#    male_percentage  female_percentage  season                notes
# 0               43                 57  Spring          High demand
# 1               45                 55  Summer   No issues reported
# 2               52                 48  Summer  Excellent condition
# 3               48                 52  Autumn    Needs maintenance
# 4               48                 52  Summer   No issues reported

# %%
res_land_price.head()
# Out:
#            CBSA  CBSA Code  Year  Land Value (Per Acre, As-Is)  \
# 0  Aberdeen, SD      10100  2012                         72000
# 1  Aberdeen, SD      10100  2013                         75900
# 2  Aberdeen, SD      10100  2014                         62300
# 3  Aberdeen, SD      10100  2015                         65100
# 4  Aberdeen, SD      10100  2016                         98400
#
#    Land Value (1/4 Acre Lot, Standardized)  Land Share of Property Value  \
# 0                                    21800                         0.122
# 1                                    23000                         0.125
# 2                                    18900                         0.101
# 3                                    19700                         0.105
# 4                                    29800                         0.150
#
#    Home Price Appreciation (HPA)
# 0                          1.000
# 1                          1.025
# 2                          1.037
# 3                          1.050
# 4                          1.105

# %% [markdown]
# CBSA stands for core-based statistical area. It is roughly equivalent to major cities. I plan to integrate shelters and land price on this feature. I will split the CBSA values into City and State to do so.
#
# https://en.wikipedia.org/wiki/List_of_core-based_statistical_areas
#
# https://www.bls.gov/tus/dictionaries/gtcbsa_gtco_aug_2015.pdf

# %% [markdown]
# #### Checking for Missing Values

# %%
shelters.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 1000 non-null   int64
#  1   date               1000 non-null   str
#  2   shelter_name       1000 non-null   str
#  3   city               1000 non-null   str
#  4   state              1000 non-null   str
#  5   total_capacity     1000 non-null   int64
#  6   occupied_beds      1000 non-null   int64
#  7   available_beds     1000 non-null   int64
#  8   occupancy_rate     1000 non-null   float64
#  9   average_age        1000 non-null   int64
#  10  male_percentage    1000 non-null   int64
#  11  female_percentage  1000 non-null   int64
#  12  season             1000 non-null   str
#  13  notes              913 non-null    str
# dtypes: float64(1), int64(7), str(6)
# memory usage: 109.5 KB

# %% [markdown]
# All features of the shelters dataframe have non-null values except notes. I don't plan on analyzing the notes feature, so we can ignore that missing notes data. If I decide to recommend sentiment analysis of the notes for future research, then those missing values would need to be addressed.

# %%
res_land_price.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11206 entries, 0 to 11205
# Data columns (total 7 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   CBSA                                     11206 non-null  str
#  1   CBSA Code                                11206 non-null  int64
#  2   Year                                     11206 non-null  int64
#  3   Land Value (Per Acre, As-Is)             11206 non-null  int64
#  4   Land Value (1/4 Acre Lot, Standardized)  11206 non-null  int64
#  5   Land Share of Property Value             11206 non-null  float64
#  6   Home Price Appreciation (HPA)            11206 non-null  float64
# dtypes: float64(2), int64(4), str(1)
# memory usage: 613.0 KB

# %% [markdown]
# All features of the residential land price dataframe have non-null values.

# %% [markdown]
# #### Overview of the Data Distributions

# %%
shelters.describe()
# Out:
#                 id  total_capacity  occupied_beds  available_beds  \
# count  1000.000000     1000.000000    1000.000000     1000.000000
# mean    500.500000      179.123000      91.874000       87.249000
# std     288.819436       73.419195      67.068937       65.531224
# min       1.000000       50.000000       0.000000        0.000000
# 25%     250.750000      115.000000      38.000000       35.000000
# 50%     500.500000      182.000000      76.000000       71.000000
# 75%     750.250000      243.000000     136.000000      128.250000
# max    1000.000000      300.000000     294.000000      296.000000
#
#        occupancy_rate  average_age  male_percentage  female_percentage
# count     1000.000000  1000.000000      1000.000000        1000.000000
# mean        51.214700    42.037000        54.634000          45.366000
# std         28.880331    13.768122         8.797468           8.797468
# min          0.000000    18.000000        40.000000          30.000000
# 25%         26.775000    30.000000        47.000000          38.000000
# 50%         51.850000    42.000000        55.000000          45.000000
# 75%         76.800000    54.000000        62.000000          53.000000
# max        100.000000    65.000000        70.000000          60.000000

# %%
res_land_price.describe()
# Out:
#           CBSA Code          Year  Land Value (Per Acre, As-Is)  \
# count  11206.000000  11206.000000                  1.120600e+04
# mean   29862.737819   2018.000000                  2.538533e+05
# std    11406.387273      3.741824                  5.216632e+05
# min    10100.000000   2012.000000                 -9.230000e+04
# 25%    20020.000000   2015.000000                  6.140000e+04
# 50%    29920.000000   2018.000000                  1.182500e+05
# 75%    39780.000000   2021.000000                  2.441000e+05
# max    49820.000000   2024.000000                  9.941600e+06
#
#        Land Value (1/4 Acre Lot, Standardized)  Land Share of Property Value  \
# count                             1.120600e+04                  11206.000000
# mean                              8.811862e+04                      0.315959
# std                               1.272137e+05                      0.142970
# min                              -2.920000e+04                     -0.298000
# 25%                               2.750000e+04                      0.208000
# 50%                               5.010000e+04                      0.296000
# 75%                               9.577500e+04                      0.411000
# max                               1.927200e+06                      0.838000
#
#        Home Price Appreciation (HPA)
# count                   11206.000000
# mean                        1.441001
# std                         0.449742
# min                         0.688000
# 25%                         1.086000
# 50%                         1.288000
# 75%                         1.693000
# max                         3.555000

# %% [markdown]
# ### Integrating the Data
# First, preparing the res_land_price df for merging the tables:

# %%
res_land_price[['City', 'State']] = res_land_price['CBSA'].str.split(', ', expand=True)

# %%
res_land_price.head()
# Out:
#            CBSA  CBSA Code  Year  Land Value (Per Acre, As-Is)  \
# 0  Aberdeen, SD      10100  2012                         72000
# 1  Aberdeen, SD      10100  2013                         75900
# 2  Aberdeen, SD      10100  2014                         62300
# 3  Aberdeen, SD      10100  2015                         65100
# 4  Aberdeen, SD      10100  2016                         98400
#
#    Land Value (1/4 Acre Lot, Standardized)  Land Share of Property Value  \
# 0                                    21800                         0.122
# 1                                    23000                         0.125
# 2                                    18900                         0.101
# 3                                    19700                         0.105
# 4                                    29800                         0.150
#
#    Home Price Appreciation (HPA)      City State
# 0                          1.000  Aberdeen    SD
# 1                          1.025  Aberdeen    SD
# 2                          1.037  Aberdeen    SD
# 3                          1.050  Aberdeen    SD
# 4                          1.105  Aberdeen    SD

# %%
shelters.rename(columns={'city': 'City'}, inplace=True)

# %%
shelter_land_price = pd.merge(shelters, res_land_price, how='inner', on='City')

# %%
res_land_price.drop('State', axis=1, inplace=True)
res_land_price.drop('CBSA', axis=1, inplace=True)

# %% [markdown]
# ### Quick Look at the Integrated Data

# %%
shelter_land_price.head()
# Out:
#    id        date     shelter_name    City state  total_capacity  \
# 0   1  2023-10-05  Sunrise Shelter  Dallas    TX              85
# 1   1  2023-10-05  Sunrise Shelter  Dallas    TX              85
# 2   1  2023-10-05  Sunrise Shelter  Dallas    TX              85
# 3   1  2023-10-05  Sunrise Shelter  Dallas    TX              85
# 4   1  2023-10-05  Sunrise Shelter  Dallas    TX              85
#
#    occupied_beds  available_beds  occupancy_rate  average_age  ...  season  \
# 0             62              23            72.9           19  ...  Spring
# 1             62              23            72.9           19  ...  Spring
# 2             62              23            72.9           19  ...  Spring
# 3             62              23            72.9           19  ...  Spring
# 4             62              23            72.9           19  ...  Spring
#
#          notes        CBSA CBSA Code  Year  Land Value (Per Acre, As-Is)  \
# 0  High demand  Dallas, TX     19100  2012                        165200
# 1  High demand  Dallas, TX     19100  2013                        195900
# 2  High demand  Dallas, TX     19100  2014                        228500
# 3  High demand  Dallas, TX     19100  2015                        284700
# 4  High demand  Dallas, TX     19100  2016                        352800
#
#    Land Value (1/4 Acre Lot, Standardized)  Land Share of Property Value  \
# 0                                    45200                         0.274
# 1                                    53600                         0.303
# 2                                    62500                         0.330
# 3                                    77900                         0.376
# 4                                    96500                         0.428
#
#    Home Price Appreciation (HPA)  State
# 0                          1.000     TX
# 1                          1.073     TX
# 2                          1.149     TX
# 3                          1.255     TX
# 4                          1.366     TX
#
# [5 rows x 22 columns]

# %%
shelter_land_price.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13000 entries, 0 to 12999
# Data columns (total 22 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   id                                       13000 non-null  int64
#  1   date                                     13000 non-null  str
#  2   shelter_name                             13000 non-null  str
#  3   City                                     13000 non-null  str
#  4   state                                    13000 non-null  str
#  5   total_capacity                           13000 non-null  int64
#  6   occupied_beds                            13000 non-null  int64
#  7   available_beds                           13000 non-null  int64
#  8   occupancy_rate                           13000 non-null  float64
#  9   average_age                              13000 non-null  int64
#  10  male_percentage                          13000 non-null  int64
#  11  female_percentage                        13000 non-null  int64
#  12  season                                   13000 non-null  str
#  13  notes                                    11869 non-null  str
#  14  CBSA                                     13000 non-null  str
#  15  CBSA Code                                13000 non-null  int64
#  16  Year                                     13000 non-null  int64
#  17  Land Value (Per Acre, As-Is)             13000 non-null  int64
#  18  Land Value (1/4 Acre Lot, Standardized)  13000 non-null  int64
#  19  Land Share of Property Value             13000 non-null  float64
#  20  Home Price Appreciation (HPA)            13000 non-null  float64
#  21  State                                    13000 non-null  str
# dtypes: float64(3), int64(11), str(8)
# memory usage: 2.2 MB

# %%
shelter_land_price.describe()
# Out:
#                  id  total_capacity  occupied_beds  available_beds  \
# count  13000.000000    13000.000000   13000.000000     13000.00000
# mean     500.500000      179.123000      91.874000        87.24900
# std      288.686094       73.385299      67.037973        65.50097
# min        1.000000       50.000000       0.000000         0.00000
# 25%      250.750000      115.000000      38.000000        35.00000
# 50%      500.500000      182.000000      76.000000        71.00000
# 75%      750.250000      243.000000     136.000000       128.25000
# max     1000.000000      300.000000     294.000000       296.00000
#
#        occupancy_rate   average_age  male_percentage  female_percentage  \
# count    13000.000000  13000.000000     13000.000000       13000.000000
# mean        51.214700     42.037000        54.634000          45.366000
# std         28.866998     13.761766         8.793406           8.793406
# min          0.000000     18.000000        40.000000          30.000000
# 25%         26.775000     30.000000        47.000000          38.000000
# 50%         51.850000     42.000000        55.000000          45.000000
# 75%         76.800000     54.000000        62.000000          53.000000
# max        100.000000     65.000000        70.000000          60.000000
#
#           CBSA Code          Year  Land Value (Per Acre, As-Is)  \
# count  13000.000000  13000.000000                  1.300000e+04
# mean   32563.080000   2018.000000                  1.808040e+06
# std     9033.388578      3.741801                  2.052428e+06
# min    16980.000000   2012.000000                  1.195000e+05
# 25%    26420.000000   2015.000000                  4.125000e+05
# 50%    35620.000000   2018.000000                  8.154000e+05
# 75%    41700.000000   2021.000000                  2.693000e+06
# max    41940.000000   2024.000000                  9.489900e+06
#
#        Land Value (1/4 Acre Lot, Standardized)  Land Share of Property Value  \
# count                             1.300000e+04                  13000.000000
# mean                              4.021773e+05                      0.495640
# std                               4.259935e+05                      0.154481
# min                               3.170000e+04                      0.211000
# 25%                               1.029000e+05                      0.382000
# 50%                               2.036000e+05                      0.469000
# 75%                               5.781000e+05                      0.607000
# max                               1.927200e+06                      0.788000
#
#        Home Price Appreciation (HPA)
# count                   13000.000000
# mean                        1.639999
# std                         0.528874
# min                         1.000000
# 25%                         1.206000
# 50%                         1.485000
# 75%                         1.946000
# max                         3.145000

# %%
shelter_land_price.hist(column="Land Value (Per Acre, As-Is)")
# Out:
# array([[<Axes: title={'center': 'Land Value (Per Acre, As-Is)'}>]],
#       dtype=object)

# %%
shelter_land_price.plot.scatter("Land Value (Per Acre, As-Is)", "total_capacity")
# Out:
# <Axes: xlabel='Land Value (Per Acre, As-Is)', ylabel='total_capacity'>

# %%
shelter_land_price.loc[shelter_land_price['Land Value (Per Acre, As-Is)'] == 9.489900e+06]
# Out:
#         id        date        shelter_name      City state  total_capacity  \
# 38       3  2025-04-27       Second Chance  San Jose    CA             190
# 51       4  2024-10-05         Harbor Home  San Jose    CA             115
# 77       6  2023-09-29         Harbor Home  San Jose    CA              81
# 298     23  2024-06-08            HomeSafe  San Jose    CA             271
# 376     29  2025-02-07  Recovery Residence  San Jose    CA              91
# ...    ...         ...                 ...       ...   ...             ...
# 12401  954  2025-07-08       Second Chance  San Jose    CA             210
# 12479  960  2023-11-19        Shelter Plus  San Jose    CA             132
# 12921  994  2024-11-30         Harbor Home  San Jose    CA             265
# 12947  996  2023-11-14      New Beginnings  San Jose    CA             205
# 12960  997  2025-03-09         Harbor Home  San Jose    CA              60
#
#        occupied_beds  available_beds  occupancy_rate  average_age  ...  \
# 38               144              46            75.8           56  ...
# 51                 7             108             6.1           63  ...
# 77                61              20            75.3           41  ...
# 298              271               0           100.0           30  ...
# 376               15              76            16.5           62  ...
# ...              ...             ...             ...          ...  ...
# 12401            124              86            59.0           36  ...
# 12479            126               6            95.5           21  ...
# 12921            121             144            45.7           41  ...
# 12947            199               6            97.1           45  ...
# 12960             16              44            26.7           59  ...
#
#        season                notes          CBSA CBSA Code  Year  \
# 38     Summer  Excellent condition  San Jose, CA     41940  2024
# 51     Autumn    Needs maintenance  San Jose, CA     41940  2024
# 77     Autumn   No issues reported  San Jose, CA     41940  2024
# 298    Autumn   Recently renovated  San Jose, CA     41940  2024
# 376    Autumn                  NaN  San Jose, CA     41940  2024
# ...       ...                  ...           ...       ...   ...
# 12401  Spring       Staff shortage  San Jose, CA     41940  2024
# 12479  Summer          High demand  San Jose, CA     41940  2024
# 12921  Summer       Staff shortage  San Jose, CA     41940  2024
# 12947  Winter   Recently renovated  San Jose, CA     41940  2024
# 12960  Spring    Needs maintenance  San Jose, CA     41940  2024
#
#        Land Value (Per Acre, As-Is)  Land Value (1/4 Acre Lot, Standardized)  \
# 38                          9489900                                  1927200
# 51                          9489900                                  1927200
# 77                          9489900                                  1927200
# 298                         9489900                                  1927200
# 376                         9489900                                  1927200
# ...                             ...                                      ...
# 12401                       9489900                                  1927200
# 12479                       9489900                                  1927200
# 12921                       9489900                                  1927200
# 12947                       9489900                                  1927200
# 12960                       9489900                                  1927200
#
#        Land Share of Property Value  Home Price Appreciation (HPA)  State
# 38                            0.782                          2.734     CA
# 51                            0.782                          2.734     CA
# 77                            0.782                          2.734     CA
# 298                           0.782                          2.734     CA
# 376                           0.782                          2.734     CA
# ...                             ...                            ...    ...
# 12401                         0.782                          2.734     CA
# 12479                         0.782                          2.734     CA
# 12921                         0.782                          2.734     CA
# 12947                         0.782                          2.734     CA
# 12960                         0.782                          2.734     CA
#
# [90 rows x 22 columns]

# %% [markdown]
# ## Next: PowerBI
# Exporting the data as csv to load it into PowerBI for further analysis and visualizations:

# %%
shelter_land_price.to_csv("shelter_land_price.csv")
